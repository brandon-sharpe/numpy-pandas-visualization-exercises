# %% [markdown]
# # Exercises to help me practice mathplotlib

# %% [markdown]
# ## Exercises

# %% [markdown]
# ## 1

# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y=x2−x+2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt
import math

# %%
x = range(-100, 100)
y = [(x**2 - x + 2) for x in x]

# Plot x and y
plt.plot(x,y)

# add title
plt.title('$ y = x^2 - x +2$')

# add labels
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.annotate('Origin', xy = (0,0), xytext = (0, 3000), arrowprops ={})
# %config InlineBackend.figure_format = 'png'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-38fd14790384> in <module>
#       6
#       7 # add title
# ----> 8 plt.title('$ y = x^2 - x +2$')
#       9
#      10 # add labels
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## 2.

# %% [markdown]
# Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y=√x
#
# y=x^3
#
# y=2^x
#
# y=1/(x+1)
# You can use functions from the math module to help implement some of the equations above.

# %%
xv = range(0,49)
yv = np.sqrt(xv)

plt.xlabel('$x$')
plt.ylabel('$\sqrt{x}$', rotation = 0, ha='right')
plt.plot(xv, yv)
plt.show()

# %%
x = list(range(1,8))
y = [i**3 for i in x]

plt.xlabel('$x$')
plt.ylabel('$x^3$', rotation = 0, ha='right')
plt.scatter(x, y)
plt.plot(x,y, ls='--')
plt.show()

# %%
x = list(range(1,8))
y = [2**i for i in x]

plt.xlabel('$x$')
plt.ylabel('$2^x$', rotation = 0, ha='right')
plt.scatter(x, y)
plt.plot(x,y, ls='--')
plt.show()

# %%
x = list(range(1,30))
y = [(1/(n+1)) for n in x]
plt.figure(figsize=(14, 6))
plt.scatter(x, y)

plt.plot(x,y, ls=':')
plt.show()

# %% [markdown]
# ## 3

# %% [markdown]
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(14, 6))
x = list(range(1,10))

y1 = [(n ** .5) for n in x]
y2 = [(n ** 3) for n in x]
y3 = [(2 ** n) for n in x]
y4 = [(1/ (n + 1)) for n in x]
y_list = [y1, y2, y3, y4]
titles = ['$y = \u221Ax$', '$y = x^3$', '$y = 2^x$', '$y = \dfrac{1}{(x+1)}$']

for i, y_val in enumerate(y_list):
    plt.subplot(1, 4, i+1)
    plt.plot(x, y_val)
    plt.title(titles[i])
